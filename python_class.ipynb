# %% [markdown]
# <a href="https://colab.research.google.com/github/sumina-01/Training-program/blob/main/python_class.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n=int(input("Enter total monkeys(n):"))
k=int(input("Enter bananas a monkey can eat(k):"))
j=int(input("Enter peanuts a monkey can eat(j):"))
m=int(input("Enter total bananas(m):"))
p=int(input("Enter total peanuts(p):"))
if(k==0 or j==0):
  print("invalid input")
else:
  n=n-(m//k+p//j)
  if(m%k!=0 or p%j!=0):
    n=n-1
  print("No of monkeys in tree:",n)
# Out:
# Enter total monkeys(n):20
# Enter bananas a monkey can eat(k):2
# Enter peanuts a monkey can eat(j):3
# Enter total bananas(m):12
# Enter total peanuts(p):12
# No of monkeys in tree: 10

# %%
p=int(input("Enter a number:"))
q=int(input("Enter a number:"))
p,q=q,p
print(p,q)
# Out:
# Enter a number:2
# Enter a number:5
# 5 2

# %%
p=int(input("Enter a number:"))
q=int(input("Enter a number:"))
p=p^q
q=p^q
p=p^q
print("p=",p)
print("q=",q)
# Out:
# Enter a number:5
# Enter a number:8
# p= 8
# q= 5

# %%
print("using temp")
p=int(input("Enter number:"))
q=int(input("Enter number"))
print(p,q)
temp=p
p=q
q=temp
print(p,q)
print("using ,")
p=int(input("Enter number:"))
q=int(input("Enter number"))
print(p,q)
p,q=q,p
print(p,q)
print("using +/-")
p=int(input("Enter number:"))
q=int(input("Enter number"))
print(p,q)
p=p+q
q=p-q
p=p-q
print(p,q)
print("using ^")
p=int(input("Enter number:"))
q=int(input("Enter number"))
print(p,q)
p=p^q
q=p^q
p=p^q
print(p,q)
# Out:
# using temp
# Enter number:4
# Enter number8
# 4 8
# 8 4
# using ,
# Enter number:4
# Enter number8
# 4 8
# 8 4
# using +/-
# Enter number:4
# Enter number8
# 4 8
# 8 4
# using ^
# Enter number:4
# Enter number8
# 4 8
# 8 4

# %%
n=int(input("enter no:of candies available in the jar"))
k=int(input("enter number of minimum candies that must be inside JAR ever."))
C=1
R=n
while(C==1):
  M=int(input("Enter amout of candies needed:"))
  if(M>n):
    print("invalid")
  else:
    R=R-M
    if(R<=k):
      R=n
    print("SOLD=",M)
    print("Remaining=",R)
    C=int(input("DO you want to continue(1or0):"))
# Out:
# SOLD= 2
# Remaining= 8
# SOLD= 2
# Remaining= 6

# %%
a=int(input("Enter list size:"))
list=[]
for i in range(a):
  b=str(input("Enter the elements in the list:"))
  list.append(b)
print("List:",list)
# Out:
# Enter list size:3
# Enter the elements in the list:apple
# Enter the elements in the list:grape
# Enter the elements in the list:berry
# List: ['apple', 'grape', 'berry']

# %%
a=int(input("Enter the list size:"))
list=[]
for i in range(a):
  b=int(input("Enter the number:"))
  list.append(b)
largest=list[0]
for i in range(1,a):
  if(list[i]>largest):
    largest=list[i]
print("Largest Element=",largest)
# Out:
# Enter the list size:4
# Enter the number:5
# Enter the number:6
# Enter the number:8
# Enter the number:2
# Largest Element= 8

# %%
a=int(input("Enter the list size:"))
list=[]
for i in range(a):
  b=int(input("enter the number:"))
  list.append(b)
smallest=list[0]
for i in range(1,a):
  if(list[i]<smallest):
    smallest=list[i]
print("Smallest element=",smallest)
# Out:
# Enter the list size:3
# enter the number:8
# enter the number:1
# enter the number:6
# Smallest element= 1

# %%
a=int(input("Enter the number of elements:"))
list=[]
sum=0
for i in range(a):
  b=int(input("Enter the number:"))
  list.append(b)
  sum=sum+b
print("List:",list)
print("Sum of numbers :",sum)
# Out:
# Enter the number of elements:4
# Enter the number:3
# Enter the number:2
# Enter the number:1
# Enter the number:1
# List: [3, 2, 1, 1]
# Sum of numbers : 7

# %%
a=int(input("Enter the size of array:"))
arr=[]
for i in range(a):
  el=int(input("Enter the array elements:"))
  arr.append(el)
print("Reversed array :",arr[::-1])
# Out:
# Enter the size of array:4
# Enter the array elements:5
# Enter the array elements:9
# Enter the array elements:7
# Enter the array elements:3
# Reversed array : [3, 7, 9, 5]

# %%
a=int(input("Enter the list size:"))
list=[]
for i in range(a):
  b=int(input("enter the elements:"))
  list.append(b)
k=int(input("Enter an element to be searched:"))
if k in list:
    print("Element exist!")
else:
    print("Element not exist!")
# Out:
# Enter the list size:3
# enter the elements:4
# enter the elements:5
# enter the elements:2
# Enter an element to be searched:1
# Element not exist!

# %%
a=int(input("Enter the list size:"))
list=[]
for i in range(a):
  b=int(input("Enter the elements:"))
  list.append(b)
el=int(input("Enter the element to be checked:"))
count=list.count(el)
print("Occurance of ",el,"is:",count)
# Out:
# Enter the list size:5
# Enter the elements:1
# Enter the elements:2
# Enter the elements:2
# Enter the elements:2
# Enter the elements:7
# Enter the element to be checked:2
# Occurance of  2 is: 3

# %%
a=int(input("Enter the list size:"))
list=[]
for i in range(a):
  b=int(input("Enter the elements:"))
  list.append(b)
list.sort()
print("Second largest element is:",list[-2])
# Out:
# Enter the list size:5
# Enter the elements:1
# Enter the elements:4
# Enter the elements:6
# Enter the elements:9
# Enter the elements:5
# Second largest element is: 6

# %%
n=int(input("Enter the no. of elements: "))
a=[]
for i in range(n):
  a.append(int(input("Enter the element: ")))
print("List=",a)
n=[]
for i in a:
  if i not in n:
    n.append(i)
print("Updated list=",n)
# Out:
# Enter the no. of elements: 3
# Enter the element: 4
# Enter the element: 8
# Enter the element: 4
# List= [4, 8, 4]
# Updated list= [4, 8]

# %%
a=int(input("Enter the list size:"))
list=[]
for i in range(a):
  b=int(input("Enter the elements:"))
  list.append(b)
list.sort()
print("Sorted array:",list)
# Out:
# Enter the list size:4
# Enter the elements:2
# Enter the elements:5
# Enter the elements:4
# Enter the elements:8
# Sorted array: [2, 4, 5, 8]

# %%
i=map(int,(input("Enter elements:").split()))
print(list(i))
# Out:
# Enter elements:3 4 5
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1928/2603224099.py in <cell line: 0>()
#       1 i=map(int,(input("Enter elements:").split()))
# ----> 2 print(list(i))
#
# TypeError: 'list' object is not callable

# %%
arr=[5,11,15,22,15,30]
print(arr[:])
print(arr[2:])
print(arr[:3])
print(arr[: :-1])
print(arr[1:4])
print(arr[1:5:2])
# Out:
# [5, 11, 15, 22, 15, 30]
# [15, 22, 15, 30]
# [5, 11, 15]
# [30, 15, 22, 15, 11, 5]
# [11, 15, 22]
# [11, 22]

# %%
r=int(input("Enter number of rats: "))
unit=int(input("Enter food consumed by each rat: "))
n=int(input("Enter number of houses: "))
arr=[int(x) for x in input("Enter food in each house:").split()]
if not arr:
  print(-1)
else:
    food_needed = r * unit
    food = 0
    houses = 0
    for i in range(n):
        food = food + arr[i]
        houses = houses + 1
        if food >= food_needed:
            break
    if food < food_needed:
        print(0)
    else:
        print(houses)
# Out:
# Enter number of rats: 7
# Enter food consumed by each rat: 2
# Enter number of houses: 8
# Enter food in each house:2 8 3 5 7 4 1 2
# 4

# %%
a=str(input("Enter the string:"))
print("Reversed string :",a[::-1])
# Out:
# Enter the string:apple
# Reversed string : elppa

# %%
a=int(input("Enter the number:"))
reverse=0
while a>0:
  num=a%10
  reverse=reverse*10+num
  a=a//10
print("Reversed number:",reverse)
# Out:
# Enter the number:345
# Reversed number: 543

# %%
a=int(input("Enter the number:"))
sum=0
while a>0:
  num=a%10
  sum=sum+num
  a=a//10
print("Sum of digits:",sum)
# Out:
# Enter the number:82
# Sum of digits: 10

# %%
a=int(input("Enter your number:"))
l=0
while a>0:
  num=a%10
  if num>l:
    l=num
  a=a//10
print("Largest digit:",l)
# Out:
# Enter your number:1589
# Largest digit: 9

# %%
a=int(input("Enter your number:"))
digit=a
rev=0
while a>0:
  num=a%10
  rev=rev*10+num
  a=a//10
if rev==digit:
  print("Number is palindrome")
else:
  print("Number is not palindrome")
# Out:
# Enter your number:555
# Number is palindrome

# %%
a=input("Enter the string:")
if a==a[::-1]:
  print("string is palindrome")
else:
  print("String is not palindrome")
# Out:
# Enter the string:malayalam
# string is palindrome

# %%
str1=input("enter the string:")
str2=input("enter the string:")
if(sorted(str1)==sorted(str2)):
  print("anagram")
else:
  print("not anagram")
# Out:
# enter the string:listen
# enter the string:silents
# not anagram

# %%
a=input("Enter a string: ")
count=0
for i in a:
     count+=1
print("Total characters without built in",count)
print("Total characters with built in",len(a))
# Out:
# Enter a string: banana
# Total characters without built in 6
# Total characters with built in 6

# %%
s=input("enter a string")
d=""
for ch in s:
  if ch not in d:
    d+=ch
print(d)
# Out:
# enter a stringbanana
# ban

# %%
s=input("Ënter a string:")
v=0
c=0
for i in s:
  if(i in "aeiouAEIOU"):
    v+=1
  else:
    c+=1
print("No. of vowels:",v)
print("No of consonants:",c)
# Out:
# Ënter a string:belgium
# No. of vowels: 3
# No of consonants: 4

# %%
a=input("Enter your string:")
space=""
for ch in a:
  if ch!=" ":
    space+=ch
print("The string without space:",space)
# Out:
# Enter your string:coco nut
# The string without space: coconut
